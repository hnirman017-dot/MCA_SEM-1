# %%
a=25
b=12.25
c="python"
d= rue 
print(a)
print (type(a))
print (b)
print (type(b))
print (c)
print (type(c))
print (d)
print (type(d))
# Out:
# 25
# <class 'int'>
# 12.25
# <class 'float'>
# python
# <class 'str'>
# True
# <class 'bool'>

# %%
# Out:
# 3
